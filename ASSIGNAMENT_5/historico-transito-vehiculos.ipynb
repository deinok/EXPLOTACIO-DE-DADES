# %% [markdown]
# # Assignament 5

# %% [markdown]
# At La Harinera LaMeta, six Hikvision cameras are used to control truck access authorization. These cameras include license plate recognition capabilities. Each detected plate is logged, and two images are stored per detection.
#
# The purpose of this notebook is to retrieve the raw detection data and use it to develop and fine-tune a model that improves license plate detection performance.

# %% [markdown]
# First of all we need to query our data sources. That is done with the following SQL query:
# ```sql
# SELECT
#     [Id],
#     [Matricula],
#     [LinkImagenVehiculo1],
#     [LinkImagenVehiculo2]
# FROM
#     [HistoricoTransitoVehiculos]
# ```

# %% [markdown]
# ## Install Dependencies

# %%
# !pip3 install fastai==2.8.6
# !pip3 install pandas==2.3.3
# !pip3 install requests==2.32.5
# Out:
# Requirement already satisfied: fastai==2.8.6 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (2.8.6)
# Requirement already satisfied: pip in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (25.3)
# Requirement already satisfied: packaging in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (25.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (0.0.7)
# Requirement already satisfied: fastcore>=1.8.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (1.9.5)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (0.24.1)
# Requirement already satisfied: matplotlib in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (3.10.8)
# Requirement already satisfied: pandas in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (2.3.3)
# Requirement already satisfied: requests in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (2.32.5)
# Requirement already satisfied: pyyaml in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (6.0.3)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (12.0.0)
# Requirement already satisfied: scikit-learn in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (1.8.0)
# Requirement already satisfied: scipy in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (1.16.3)
# Requirement already satisfied: spacy<4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (3.8.11)
# Requirement already satisfied: plum-dispatch in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (2.6.1)
# Requirement already satisfied: cloudpickle in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (3.1.2)
# Requirement already satisfied: torch<2.10,>=1.10 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai==2.8.6) (2.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (0.20.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (2.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai==2.8.6) (80.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai==2.8.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai==2.8.6) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai==2.8.6) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai==2.8.6) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai==2.8.6) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai==2.8.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai==2.8.6) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai==2.8.6) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai==2.8.6) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai==2.8.6) (0.1.5)
# Requirement already satisfied: filelock in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai==2.8.6) (3.20.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai==2.8.6) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai==2.8.6) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai==2.8.6) (2025.12.0)
# Requirement already satisfied: colorama in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai==2.8.6) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy<4->fastai==2.8.6) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai==2.8.6) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai==2.8.6) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy<4->fastai==2.8.6) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from sympy>=1.13.3->torch<2.10,>=1.10->fastai==2.8.6) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from jinja2->spacy<4->fastai==2.8.6) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai==2.8.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai==2.8.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai==2.8.6) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai==2.8.6) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai==2.8.6) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai==2.8.6) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai==2.8.6) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas->fastai==2.8.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas->fastai==2.8.6) (2025.3)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from plum-dispatch->fastai==2.8.6) (0.22.9)
# Requirement already satisfied: rich>=10.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from plum-dispatch->fastai==2.8.6) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from rich>=10.0->plum-dispatch->fastai==2.8.6) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from rich>=10.0->plum-dispatch->fastai==2.8.6) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->fastai==2.8.6) (0.1.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from scikit-learn->fastai==2.8.6) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from scikit-learn->fastai==2.8.6) (3.6.0)
# Requirement already satisfied: pandas==2.3.3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas==2.3.3) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas==2.3.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas==2.3.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas==2.3.3) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.3.3) (1.17.0)
# Requirement already satisfied: requests==2.32.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests==2.32.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests==2.32.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests==2.32.5) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests==2.32.5) (2025.11.12)

# %%
from fastai.vision.augment import Resize, aug_transforms
from fastai.vision.data import ImageDataLoaders
from fastai.vision.learner import vision_learner
from fastai.vision.utils import get_image_files
from pandas import read_csv
from pathlib import Path
from requests import get

# %% [markdown]
# ## Load CSV

# %% [markdown]
# So, first of all we need to clean up a bit the CSV, we are just going to drop any row that have a NULL.

# %%
data_frame = read_csv("./historico-transito-vehiculos.csv", header=0, sep=",") \
    .sort_values(by="Id", ascending=False) \
    .dropna()
data_frame.head()
# Out:
#             Id Matricula  \
# 178937  210315   1418LZH
# 178936  210314   6654MJZ
# 178935  210313   2514JMT
# 178934  210312   8237LZR
# 178933  210311   3309LNK
#
#                                                                                                                                                                                                                                                         LinkImagenVehiculo1  \
# 178937  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-14/20251222173414047/image-1.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178936  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-17/20251222173004383/image-1.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178935  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-16/20251222172834284/image-1.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178934  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-16/20251222172750187/image-1.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178933   https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-3/20251222172519844/image-1.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
#
#                                                                                                                                                                                                                                                         LinkImagenVehiculo2
# 178937  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-14/20251222173414047/image-2.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178936  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-17/20251222173004383/image-2.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178935  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-16/20251222172834284/image-2.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178934  https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-16/20251222172750187/image-2.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D
# 178933   https://stgghlmtransauto01.blob.core.windows.net/hmeta/camera-3/20251222172519844/image-2.jpeg?sv=2024-11-04&ss=bfqt&srt=sco&spr=https&st=2025-04-25T09%3A20%3A29Z&se=2099-04-25T17%3A20%3A29Z&sp=rwdlacupiytfx&sig=MWuV9Cego0h9INateVuXk5VShFrqMYwVmOx7A8cHHjI%3D

# %% [markdown]
# ## Download Images

# %% [markdown]
# Now that we have an in-memory version of the CSV, let's download the images.
# Some links can be old and will throw a NotAuthorized.
#
# So the aproach is that inside a folder called `images` we will create a folder with it's id. But depending on the id (if ends with 0) it will go to test, else to train. Like `images/{test|train}/{id}`, inside we will add the two images where the first part will be the `Matricula` so they will end like this: `./images/{test|train}/{id}/{row.Matricula}-{link1|link2}.jpeg`
#
# That will help us in the future.
#
# Also, they will only try to download the file if the file does not exist. That will allow some kind of pause / resume system.

# %%
base_path = Path("./images/")
train_path = base_path / "train"
test_path = base_path / "test"

for row in data_frame.itertuples(index=False):
    row_path = test_path / f"{row.Id}" if str(row.Id).endswith("0") else train_path / f"{row.Id}"
    row_path.mkdir(parents=True, exist_ok=True)
    image1_path = row_path / f"{row.Matricula}-link1.jpeg"
    image2_path = row_path / f"{row.Matricula}-link2.jpeg"
    if not image1_path.exists():
        with get(row.LinkImagenVehiculo1) as response:
            if response.ok:
                with open(image1_path, "wb") as file:
                    file.write(response.content)
                    file.flush()
    if not image2_path.exists():
        with get(row.LinkImagenVehiculo2) as response:
            if response.ok:
                with open(image2_path, "wb") as file:
                    file.write(response.content)
                    file.flush()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 17
#      15                 file.flush()
#      16 if not image2_path.exists():
# ---> 17     with get(row.LinkImagenVehiculo2) as response:
#      18         if response.ok:
#      19             with open(image2_path, "wb") as file:
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\deinok\EXPLOTACIO-DE-DADES\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train

# %% [markdown]
# First of all let's split the two datasets

# %%
data_train = Path("./images/train/")
print(data_train)

data_test = Path("./images/test/")
print(data_test)

fnames = get_image_files(data_train, recurse=True)
print(fnames[-3:])

pattern = r'(paper|rock|scissors)'

data = ImageDataLoaders.from_name_re(
    data_train, fnames, pattern, item_tfms=Resize(460), batch_tfms=aug_transforms(size=224))
# Out:
# images\train
# images\test
# [Path('images/train/210314/6654MJZ-link2.jpeg'), Path('images/train/210315/1418LZH-link1.jpeg'), Path('images/train/210315/1418LZH-link2.jpeg')]

# %% [markdown]
# # The project was abandonated at this point

# %% [markdown]
# Plate licences is not a problem that matches with the Image Classification.
#
# See the other notebook for the correct one.

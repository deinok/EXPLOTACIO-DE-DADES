# %% [markdown]
# ## Checking if using GPU

# %%
# !nvidia-smi
# %pip install fastai
# %pip install kagglehub
# Out:
# 'nvidia-smi' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: fastai in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (2.8.5)
# Requirement already satisfied: pip in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (25.3)
# Requirement already satisfied: packaging in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (25.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.9,>=1.8.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (1.8.16)
# Requirement already satisfied: fasttransform>=0.0.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (0.0.2)
# Requirement already satisfied: torchvision>=0.11 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (0.24.1)
# Requirement already satisfied: matplotlib in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (3.10.7)
# Requirement already satisfied: pandas in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (2.3.3)
# Requirement already satisfied: requests in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (2.32.5)
# Requirement already satisfied: pyyaml in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (6.0.3)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (12.0.0)
# Requirement already satisfied: scikit-learn in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (1.7.2)
# Requirement already satisfied: scipy in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (1.16.3)
# Requirement already satisfied: spacy<4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (3.8.11)
# Requirement already satisfied: plum-dispatch in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (2.6.0)
# Requirement already satisfied: cloudpickle in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (3.1.2)
# Requirement already satisfied: torch<2.10,>=1.10 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from fastai) (2.9.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (0.20.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (2.3.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (2.12.5)
# Requirement already satisfied: jinja2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from spacy<4->fastai) (80.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->fastai) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: filelock in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai) (3.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from torch<2.10,>=1.10->fastai) (2025.12.0)
# Requirement already satisfied: colorama in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from typer-slim<1.0.0,>=0.3.0->spacy<4->fastai) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from weasel<0.5.0,>=0.4.2->spacy<4->fastai) (7.5.0)
# Requirement already satisfied: wrapt in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy<4->fastai) (2.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from sympy>=1.13.3->torch<2.10,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from jinja2->spacy<4->fastai) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from matplotlib->fastai) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas->fastai) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from pandas->fastai) (2025.2)
# Requirement already satisfied: beartype>=0.16.2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from plum-dispatch->fastai) (0.22.8)
# Requirement already satisfied: rich>=10.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from plum-dispatch->fastai) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from rich>=10.0->plum-dispatch->fastai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from rich>=10.0->plum-dispatch->fastai) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->fastai) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from scikit-learn->fastai) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from scikit-learn->fastai) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: kagglehub in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->kagglehub) (2.6.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from requests->kagglehub) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\deinok\explotacio-de-dades\.venv\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Necessary imports

# %%
from fastai.vision.all import *
from fastai.metrics import error_rate
from kagglehub import dataset_download

# %% [markdown]
# ## Dataset
#
#
# If you are running this in your own machine, once you have done this step and the following one (pepare the data), you can skip them, as you'll have already the data ready.
#
# If you are running this on colab (or similar platforms), as each time you are connected to a different runtime your hard disk is from a new machine, you'll have to do these steps. Unless you are using google drive to store the data, then, this data will be stored there, and you'll already have it always (although you have to connect to google drive each time).
#
#
#
# **Another** thing that's included with fastai (besides tools for creating and training neural networks) is a collection of URLs of some of the most used datasets available (and they are stored on amazon's AWS, so we can easily download them into our machines).

# %%
path = Path(dataset_download("sanikamal/rock-paper-scissors-dataset"))

# %% [markdown]
# We'll use one of the provided datasets with FAST.AI. This one has dog and cat images.

# %%
path.ls()
# Out:
# (#1) [Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors')]

# %% [markdown]
# As you can see, we have some subdirectories on this dataset (each one is organized differently). In this case, we have a train, test, and validation directory

# %% [markdown]
# ## Creating dataloaders

# %%
data_train = path / "Rock-Paper-Scissors/Rock-Paper-Scissors/train"
print(data_train)

data_test = path / "Rock-Paper-Scissors/Rock-Paper-Scissors/test"
print(data_test)

data_validation = path / "Rock-Paper-Scissors/Rock-Paper-Scissors/validation"
print(data_validation)
# Out:
# C:\Users\deinok\.cache\kagglehub\datasets\sanikamal\rock-paper-scissors-dataset\versions\1\Rock-Paper-Scissors\Rock-Paper-Scissors\train
# C:\Users\deinok\.cache\kagglehub\datasets\sanikamal\rock-paper-scissors-dataset\versions\1\Rock-Paper-Scissors\Rock-Paper-Scissors\test
# C:\Users\deinok\.cache\kagglehub\datasets\sanikamal\rock-paper-scissors-dataset\versions\1\Rock-Paper-Scissors\Rock-Paper-Scissors\validation

# %% [markdown]
# We get all the filenames of the train part of the dataset (for a *real* example we should do this with train, valid, and test directories, sepparately

# %%
fnames = get_image_files(data_train, recurse=True)

# %% [markdown]
# We take a look at some filenames

# %%
fnames[-3:], fnames[:-3]
# Out:
# ((#3) [Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/scissors/testscissors03-117.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/scissors/testscissors03-118.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/scissors/testscissors03-119.png')],
#  (#2517) [Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-000.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-001.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-002.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-003.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-004.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-005.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-006.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-007.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-008.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-009.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-010.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-011.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-012.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-013.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-014.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-015.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-016.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-017.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-018.png'),Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/paper/paper01-019.png')...])

# %% [markdown]
# We cab see they are classified as cats and dogs, and filenames follow a pattern:
#
# ~~~
# [paper|rock|scissors]<other-things>.png
# ~~~

# %% [markdown]
# This will allow us to assign labels to the images based on the filename, and use a regular expression (regex) to do that (as fastai provides with a method to apply a regex to filenames to get labels).

# %%
pattern = r'(paper|rock|scissors)'

# %% [markdown]
# We now create the dataloader from our dataset, resizing images to 460px first, and then to 224px for training (to fit more and better on the GPU).

# %%
data = ImageDataLoaders.from_name_re(
    data_train, fnames, pattern, item_tfms=Resize(460), batch_tfms=aug_transforms(size=224) )

# %% [markdown]
# ## Neural Network

# %% [markdown]
# We create our neuralnetwork, starting with RESNET34.

# %%
learn = vision_learner(data, resnet34, metrics=error_rate)

# %% [markdown]
# We find the learning rate.

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0014454397605732083)

# %% [markdown]
# We now can train the network (fit_one_cycle changes LR during training).

# %%
learn.fit_one_cycle(4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.871635</td>
#       <td>0.036219</td>
#       <td>0.015873</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.336373</td>
#       <td>0.005963</td>
#       <td>0.001984</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.166767</td>
#       <td>0.000736</td>
#       <td>0.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.093886</td>
#       <td>0.000763</td>
#       <td>0.000000</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We save the model, so we can use it for inference faster.

# %%
learn.save('round1')
# Out:
# Path('C:/Users/deinok/.cache/kagglehub/datasets/sanikamal/rock-paper-scissors-dataset/versions/1/Rock-Paper-Scissors/Rock-Paper-Scissors/train/models/round1.pth')

# %% [markdown]
# ## Inference

# %% [markdown]
# We can create a new neural network, same characteristics as previous one

# %%
learn2 = vision_learner(data, resnet34, metrics=error_rate)

# %% [markdown]
# And load it with the saved weights to skip training.

# %%
learn2 = learn2.load('round1')

# %% [markdown]
# We have utility classes (ClassificationInterpretation) to run interpretation for classifiers.

# %%
interp = ClassificationInterpretation.from_learner(learn2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# We can compute the performance of our classifier.

# %%
losses, idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
